# %% [markdown]
# # install jupyter on ubuntu 20.04
#
# On ubuntu OS, install and run jupyter notebook on virtal enviroment
#
# - create virtual environment `virtualenv env`
# - install jupyter `pip3 install jupyter`
# - activate virtual enviroment `source env/bin/activate`
# - run jupyter notebook `jupyter notebook`
#
# *Note*
# jupyter notebook use the python packages in virtual environment

# %%
#check python version
# !python3 --version
# Out:
# Python 3.8.10

# %%
# check dependencies
# !pip3 list
# Out:
# Package                  Version
# ------------------------ -----------
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# asttokens                2.2.1
# attrs                    22.2.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# cffi                     1.15.1
# comm                     0.1.2
# debugpy                  1.6.4
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# idna                     3.4
# importlib-metadata       5.2.0
# importlib-resources      5.10.1
# ipykernel                6.19.4
# ipython                  8.7.0
# ipython-genutils         0.2.0
# ipywidgets               8.0.4
# jedi                     0.18.2
# Jinja2                   3.1.2
# jsonschema               4.17.3
# jupyter                  1.0.0
# ...

# %% [markdown]
# # Documents
#
# [dive into ocr](https://github.com/PaddlePaddle/PaddleOCR/blob/release/2.6/doc/doc_en/ocr_book_en.md)
#
# [paddle ocr](https://github.com/PaddlePaddle/PaddleOCR)
#
# [keras-ocr](https://github.com/faustomorales/keras-ocr)
#
# [craft-text-detector](https://github.com/fcakyon/craft-text-detector)
#
# [craft-pytorch](https://github.com/clovaai/CRAFT-pytorch)

# %%
# install paddle-ocr
#pip3 install paddleocr
# !pip3 install paddlepaddle
# Out:
# ...
#   Using cached paddlepaddle-2.4.1-cp38-cp38-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#   Using cached paddle_bfloat-0.1.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
# ...
#   Using cached numpy-1.24.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#   Using cached Pillow-9.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# ...
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# ...
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# ...
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# ...

# %%
import paddle

# %%
for i in dir(paddle):
    print(i)
# Out:
# CPUPlace
# CUDAPinnedPlace
# CUDAPlace
# CustomPlace
# DataParallel
# DatasetFactory
# IPUPlace
# InMemoryDataset
# LazyGuard
# MLUPlace
# Model
# NPUPlace
# ParamAttr
# QueueDataset
# Tensor
# XPUPlace
# _C_ops
# __all__
# __builtins__
# __cached__
# __doc__
# __file__
# __git_commit__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# __version__
# _legacy_C_ops
# abs
# acos
# acosh
# add
# add_n
# addmm
# all
# allclose
# amax
# amin
# amp
# angle
# any
# arange
# argmax
# argmin
# argsort
# as_complex
# as_real
# asin
# asinh
# assign
# atan
# atan2
# atanh
# audio
# autograd
# batch
# bernoulli
# bfloat16
# bincount
# bitwise_and
# bitwise_not
# bitwise_or
# bitwise_xor
# bmm
# bool
# broadcast_shape
# broadcast_tensors
# broadcast_to
# bucketize
# callbacks
# cast
# ceil
# check_shape
# cholesky
# chunk
# clip
# clone
# common_ops_import
# compat
# complex
# complex128
# complex64
# concat
# conj
# cos
# cosh
# count_nonzero
# create_parameter
# crop
# cross
# ...

# %%
#install keras-ocr
# !pip3 install keras-ocr
# !pip3 install tensorflow
# Out:
# ...
#   Using cached keras_ocr-0.9.2-py3-none-any.whl (42 kB)
# ...
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Processing /home/greystone/.cache/pip/wheels/19/09/72/3eb74d236bb48bd0f3c6c3c83e4e0c5bbfcbcad7c6c3539db8/validators-0.20.0-py3-none-any.whl
# ...
#   Using cached editdistance-0.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# ...
#   Using cached pyclipper-1.3.0.post4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (619 kB)
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached essential_generators-1.0-py3-none-any.whl (9.5 MB)
# ...
#   Using cached efficientnet-1.0.0-py3-none-any.whl (17 kB)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# ...
#   Using cached shapely-2.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# ...
#   Using cached imageio-2.23.0-py3-none-any.whl (3.4 MB)
# ...
#   Using cached scipy-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# ...

# %%
import matplotlib.pyplot as plt
import keras_ocr
import matplotlib.image as mpimg
import os
import random
# Out:
# 2022-12-24 09:50:00.961729: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:246: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# 2022-12-24 09:50:01.469229: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages/cv2/../../lib64:/usr/local/cuda-11.4/lib64
# ...

# %%
def detect(file):
    image = keras_ocr.tools.read(file)
    detector = keras_ocr.detection.Detector(weights='clovaai_general')
    boxes = detector.detect(images=[image])[0] # print(boxes)
    image = keras_ocr.tools.drawBoxes(image=image,boxes=boxes)
    plt.figure(figsize=(10, 10))
    plt.imshow(image)
    return image,boxes

# %%
name = 'imgs/'+random.choice(os.listdir('imgs'))
output = ""
img,boxes = detect(name) # need to download model for the first time
# Out:
# Looking for /home/greystone/.keras-ocr/craft_mlt_25k.h5
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2d8c2871f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step

# %%
for i in dir(keras_ocr):
    print(i)
# Out:
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# __version__
# config
# data_generation
# datasets
# detection
# evaluation
# pipeline
# recognition
# tools

# %%
for i in dir(keras_ocr.data_generation):
    print(i)
# Out:
# LIGATURES
# LIGATURE_STRING
# PIL
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# _strip_line
# _strip_lines
# compute_transformed_contour
# convert_image_generator_to_recognizer_input
# convert_lines_to_paragraph
# cv2
# draw_text_image
# essential_generators
# fontTools
# font_supports_alphabet
# get_backgrounds
# get_fonts
# get_image_generator
# get_maximum_uniform_contour
# get_rotation_matrix
# get_text_generator
# glob
# itertools
# math
# np
# os
# random
# string
# tools
# tqdm
# typing
# zipfile

# %%
for i in dir(keras_ocr.datasets):
    print(i)
# Out:
# PIL
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# _read_born_digital_labels_file
# concurrent
# get_born_digital_recognizer_dataset
# get_cocotext_recognizer_dataset
# get_detector_image_generator
# get_icdar_2013_detector_dataset
# get_icdar_2013_recognizer_dataset
# get_icdar_2019_semisupervised_dataset
# get_recognizer_image_generator
# glob
# imgaug
# itertools
# json
# np
# os
# random
# tools
# tqdm
# typing
# warnings
# zipfile

# %%
for i in dir(keras_ocr.detection):
    print(i)
# Out:
# Detector
# PRETRAINED_WEIGHTS
# UpsampleLike
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# build_efficientnet_backbone
# build_keras_model
# build_torch_model
# build_vgg_backbone
# compute_input
# compute_maps
# cv2
# efficientnet
# getBoxes
# get_gaussian_heatmap
# invert_input
# keras
# load_torch_weights
# make_vgg_block
# map_to_rgb
# np
# tf
# tools
# typing
# upconv

# %%
for i in dir(keras_ocr.evaluation):
    print(i)
# Out:
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# copy
# cv2
# editdistance
# iou_score
# np
# pyclipper
# score
# typing
# warnings

# %%
for i in dir(keras_ocr.recognition):
    print(i)
# Out:
# CTCDecoder
# DEFAULT_ALPHABET
# DEFAULT_BUILD_PARAMS
# PRETRAINED_WEIGHTS
# Recognizer
# __annotations__
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# _meshgrid
# _repeat
# _transform
# build_model
# cv2
# keras
# np
# string
# swish
# tf
# tools
# typing

# %%
for i in dir(keras_ocr.tools):
    print(i)
# Out:
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# adjust_boxes
# augment
# combine_line
# cv2
# download_and_verify
# drawAnnotations
# drawBoxes
# fit
# fix_line
# flatten
# geometry
# get_default_cache_dir
# get_rotated_box
# get_rotated_width_height
# hashlib
# imgaug
# io
# np
# os
# pad
# plt
# read
# read_and_fit
# resize_image
# sha256sum
# spatial
# tx
# typing
# urllib
# validators
# warpBox

# %%
# install craft-text-detector
# !pip3 install craft-text-detector
# Out:
# ...
#   Using cached craft_text_detector-0.4.3-py3-none-any.whl (18 kB)
# ...
#   Using cached opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
# ...
#   Using cached gdown-4.6.0-py3-none-any.whl (14 kB)
# ...
#   Using cached torchvision-0.14.1-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
# ...
#   Using cached torch-1.13.1-cp38-cp38-manylinux1_x86_64.whl (887.4 MB)
# ...
#   Using cached filelock-3.8.2-py3-none-any.whl (10 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# ...
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# ...
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
# ...

# %%
# import Craft class
from craft_text_detector import Craft

# set image path and export folder directory
image = 'imgs/img1.jpg' # can be filepath, PIL image or numpy array
output_dir = 'outputs'

# create a craft instance
craft = Craft(output_dir=output_dir, crop_type="poly", cuda=False)

# apply craft text detection and export detected regions to output directory
prediction_result = craft.detect_text(image)

# unload models from ram/gpu
craft.unload_craftnet_model()
craft.unload_refinenet_model()

# %%
# import craft functions
from craft_text_detector import (
    read_image,
    load_craftnet_model,
    load_refinenet_model,
    get_prediction,
    export_detected_regions,
    export_extra_results,
    empty_cuda_cache
)

# set image path and export folder directory
image = 'imgs/img1.jpg' # can be filepath, PIL image or numpy array
output_dir = 'outputs'

# read image
image = read_image(image)

# load models
refine_net = load_refinenet_model(cuda=True)
craft_net = load_craftnet_model(cuda=True)

# perform prediction
prediction_result = get_prediction(
    image=image,
    craft_net=craft_net,
    refine_net=refine_net,
    text_threshold=0.7,
    link_threshold=0.4,
    low_text=0.4,
    cuda=True,
    long_size=1280
)

# export detected text regions
exported_file_paths = export_detected_regions(
    image=image,
    regions=prediction_result["boxes"],
    output_dir=output_dir,
    rectify=True
)

# export heatmap, detection points, box visualization
export_extra_results(
    image=image,
    regions=prediction_result["boxes"],
    heatmaps=prediction_result["heatmaps"],
    output_dir=output_dir
)

# unload models from gpu
empty_cuda_cache()
