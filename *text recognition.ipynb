# %% [markdown]
# # references
#
# [1](https://github.com/clovaai/deep-text-recognition-benchmark)
#
# [2](https://github.com/hwalsuklee/awesome-deep-text-detection-recognition)
#
# [3](https://github.com/zhang0jhon/AttentionOCR)
#
# [4](https://github.com/open-mmlab/mmocr)
