# %% [markdown]
# # Alias
# |No|Device|Model|Serial|Code|Alias|Note|Comment|
# |---|---|---|---|---|---|---|---|
# |01| Google Nest Learning Thermostat (Black)|H1HB1J|---|qr|
# |02| Google Nest Hello Doorbell|A0077|---|qr|
# |03| Chromecast Ultra (2016)|G2RNL|---|---|
# |04| Google Wifi (1 pk)|H2D|---|qr|
# |05| Google Nest Cam Outdoor|G3AL9|---|---|
# |06| Google Nest Cam IQ Indoor|G9Q9T|---|---|
# |07| Google Chromecast Black|NC2-6A5|---|---|
# |08| Google Nest Cam IQ Outdoor|KT1UM9|---|qr|
# |09| Google Nest Wifi Router|G6ZUC|---|qr|
# |10| Google Home Mini|H2C|---|---|
# |11| Google TV Remote|G9N9N|---|---|
# |12| Google Nest Protect smoke alarm|NEST-4895|---|qr|
# |13| Google Home|HOME|---|---|
# |14| Google Chromecast White|NC2-6A5|---|---|
# |15| Google Nest Connect range extender|A0078|---|qr|
# |16| Google Nest Wifi Pro|SNOW|---|qr+bar|
# |17| Google Nest Doorbell (Battery)|GWX3T|---|qr|
# |18| Google Nest Wifi Point|H2E|---|---|
# |19| Google Nest Power Connector|GVNZ4|---|---|
# |20| Google Nest Temperature Sensor White|T5000SF|---|---|
# |21| Google Nest Hub Max|H2A|---|---|
# |22| Google Stadia Game Controller|H2B|---|---|
# |23| Google Door Camera|ATLRQ1US|---|---|
# |24| Google Nest Hub|GUIK2|---|---|
# |25| Google Nest Learning Thermostat (White)|AK2L2R|---|---|
# |26| Google Nest Audio|GXCA6|---|---|

# %%
# !ls samples > samples/files.txt

# %%
import json

# %% [markdown]
# # 1. Code Reader

# %%
import cv2
from utils import CodeReader

# %%
# instance of CodeReader
reader = CodeReader()

# %%
img = cv2.imread('')

# %% [markdown]
# # 2. Object Classification

# %% [markdown]
# # 3. Color Classification

# %% [markdown]
# # 4. OCR
