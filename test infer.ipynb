# %% [markdown]
# # Alias

# %% [markdown]
# # 1. Code Reader

# %%
import cv2
from utils import CodeReader

# %%
# instance of CodeReader
reader = CodeReader()

# %%
img = cv2.imread('')

# %% [markdown]
# # 2. Object Classification

# %% [markdown]
# # 3. Color Classification

# %% [markdown]
# # 4. OCR
