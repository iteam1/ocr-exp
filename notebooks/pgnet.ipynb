# %% [markdown]
# # PGNet
#
# ![img](snippets/diagram/pgnet2.png)

# %% [markdown]
# install openvino dev

# %%
# 安装openvino-dev
# !pip install openvino==2022.3.0.dev20221125 -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# download inference model pgnet

# %%
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/pgnet/e2e_server_pgnetA_infer.tar
# Out:
# --2023-02-02 09:27:26--  https://paddleocr.bj.bcebos.com/dygraph_v2.0/pgnet/e2e_server_pgnetA_infer.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 195768320 (187M) [application/x-tar]
# Saving to: ‘e2e_server_pgnetA_infer.tar’
#
# e2e_server_pgnetA_i 100%[===================>] 186.70M  3.00MB/s    in 68s
#
# 2023-02-02 09:28:34 (2.76 MB/s) - ‘e2e_server_pgnetA_infer.tar’ saved [195768320/195768320]

# %%
# !tar xvf e2e_server_pgnetA_infer.tar
# !ls e2e_server_pgnetA_infer
# Out:
# e2e_server_pgnetA_infer/
# e2e_server_pgnetA_infer/inference.pdiparams
# e2e_server_pgnetA_infer/inference.pdiparams.info
# e2e_server_pgnetA_infer/inference.pdmodel
# inference.pdiparams  inference.pdiparams.info  inference.pdmodel

# %%
#!git clone https://gitee.com/paddlepaddle/PaddleOCR.git

# %% [markdown]
# copy floder imgs to PaddleOCR for inference
#
# cp -r /path/to/directory /path/to/location/new-name

# %%
# %cd paddle25
# Out:
# /home/greystone/locchuong/ocr-exp/paddle25

# %%
# !ls
# Out:
# applications  inference_results  paddleocr.py  README_ch.md	 test_tipc
# benchmark     __init__.py	 ppocr	       README.md	 tools
# configs       LICENSE		 PPOCRLabel    requirements.txt  train.sh
# deploy	      MANIFEST.in	 ppstructure   setup.py
# doc	      models		 __pycache__   StyleText

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: shapely in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: scikit-image in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.19.3)
# Requirement already satisfied: imgaug==0.4.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: pyclipper in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.3.0.post4)
# Requirement already satisfied: lmdb in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: tqdm in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.64.1)
# Requirement already satisfied: numpy in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.23.4)
# Requirement already satisfied: visualdl in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.4.2)
# Requirement already satisfied: rapidfuzz in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (2.13.7)
# Collecting opencv-contrib-python==4.4.0.46
#   Using cached opencv_contrib_python-4.4.0.46-cp38-cp38-manylinux2014_x86_64.whl (55.7 MB)
# Requirement already satisfied: cython in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.29.33)
# Requirement already satisfied: lxml in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (4.9.2)
# Requirement already satisfied: premailer in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (3.10.0)
# Requirement already satisfied: openpyxl in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (3.0.10)
# Requirement already satisfied: attrdict in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: Pillow in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: imageio in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (2.24.0)
# Requirement already satisfied: scipy in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (1.10.0)
# Requirement already satisfied: six in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: matplotlib in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (3.6.2)
# Requirement already satisfied: opencv-python in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug==0.4.0->-r requirements.txt (line 3)) (4.7.0.68)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 2)) (2022.10.10)
# Requirement already satisfied: packaging>=20.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 2)) (23.0)
# Requirement already satisfied: networkx>=2.2 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 2)) (2.8.8)
# Requirement already satisfied: requests in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (2.28.1)
# Requirement already satisfied: Flask-Babel>=1.0.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: flask>=1.1.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: bce-python-sdk in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (0.8.74)
# Requirement already satisfied: protobuf>=3.11.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (3.20.0)
# Requirement already satisfied: pandas in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (1.3.5)
# Requirement already satisfied: multiprocess in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from visualdl->-r requirements.txt (line 8)) (0.70.14)
# Requirement already satisfied: cachetools in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from premailer->-r requirements.txt (line 13)) (5.2.1)
# Requirement already satisfied: cssselect in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from premailer->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: cssutils in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from premailer->-r requirements.txt (line 13)) (2.6.0)
# Requirement already satisfied: et-xmlfile in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from openpyxl->-r requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (6.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: Babel>=2.3 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from Flask-Babel>=1.0.0->visualdl->-r requirements.txt (line 8)) (2.11.0)
# Requirement already satisfied: pytz in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from Flask-Babel>=1.0.0->visualdl->-r requirements.txt (line 8)) (2022.7)
# Requirement already satisfied: future>=0.6.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from bce-python-sdk->visualdl->-r requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from bce-python-sdk->visualdl->-r requirements.txt (line 8)) (3.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug==0.4.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: dill>=0.3.6 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from multiprocess->visualdl->-r requirements.txt (line 8)) (0.3.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from requests->visualdl->-r requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from requests->visualdl->-r requirements.txt (line 8)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from requests->visualdl->-r requirements.txt (line 8)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from requests->visualdl->-r requirements.txt (line 8)) (1.26.13)
# Requirement already satisfied: zipp>=0.5 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from Jinja2>=3.0->flask>=1.1.1->visualdl->-r requirements.txt (line 8)) (2.1.1)
# Installing collected packages: opencv-contrib-python
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.7.0.68
#     Uninstalling opencv-contrib-python-4.7.0.68:
#       Successfully uninstalled opencv-contrib-python-4.7.0.68
# Successfully installed opencv-contrib-python-4.4.0.46

# %%
# !pip install scikit-image imgaug
# Out:
# Requirement already satisfied: scikit-image in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (0.19.3)
# Requirement already satisfied: imgaug in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (23.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (1.23.4)
# Requirement already satisfied: networkx>=2.2 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (2.8.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (1.10.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (2022.10.10)
# Requirement already satisfied: imageio>=2.4.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from scikit-image) (2.24.0)
# Requirement already satisfied: opencv-python in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug) (4.7.0.68)
# Requirement already satisfied: Shapely in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug) (2.0.0)
# Requirement already satisfied: six in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: matplotlib in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from imgaug) (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/greystone/locchuong/ocr-exp/env/lib/python3.8/site-packages (from matplotlib->imgaug) (3.0.9)

# %%
# !ls ../imgs
# Out:
# 00006737.jpg  1.jpg	    img10.jpg	 img5.jpg      obj2.jpg
# 00009282.jpg  254.jpg	    img_11.jpg	 img623.jpg    straighten.jpg
# 00015504.jpg  crop_00.jpg   img11.jpg	 img6.jpg      word_10.png
# 00018069.jpg  crop_01.jpg   img_12.jpg	 img7.jpg      word_116.png
# 00056221.jpg  crop2.jpg     img12.jpg	 img8.jpg      word_19.png
# 00057937.jpg  crop_91.jpg   img13.jpg	 img9.jpg      word_201.png
# 00059985.jpg  crop_96.jpg   img14.jpg	 img.jpg       word_308.png
# 00077949.jpg  crop.jpg	    img_195.jpg  input.jpg     word_336.png
# 00111002.jpg  french_0.jpg  img2.jpeg	 japan_1.jpg   word_401.png
# 00207393.jpg  ger_1.jpg     img3.jpeg	 japan_2.jpg   word_461.png
# 11.jpg	      ger_2.jpg     img3.jpg	 korean_1.jpg  word_52.png
# 12.jpg	      img_10.jpg    img4.jpg	 obj1.jpg      word_545.png

# %% [markdown]
# !pip install Polygon3

# %%
# !python3 tools/infer/predict_e2e.py --e2e_algorithm="PGNet"\
                                    --image_dir="./doc/imgs_en/img623.jpg"\
                                    --e2e_model_dir="../e2e_server_pgnetA_infer"\
                                    --e2e_pgnet_valid_set="totaltext" --use_gpu=False
# Out:
# [2023/02/02 09:29:05] ppocr INFO: Predict time of ./doc/imgs_en/img623.jpg: 2.4220337867736816
# [2023/02/02 09:29:05] ppocr INFO: The visualized image saved in ./inference_results/e2e_res_img623.jpg

# %%
# !python3 tools/infer/predict_e2e.py --e2e_algorithm="PGNet"\
                                    --image_dir="../imgs/crop.jpg"\
                                    --e2e_model_dir="../e2e_server_pgnetA_infer"\
                                    --e2e_pgnet_valid_set="totaltext" --use_gpu=False
# Out:
# [2023/02/02 09:29:14] ppocr INFO: Predict time of ../imgs/crop.jpg: 0.52152419090271
# [2023/02/02 09:29:14] ppocr INFO: The visualized image saved in ./inference_results/e2e_res_crop.jpg

# %%
# !python3 tools/infer/predict_e2e.py --e2e_algorithm="PGNet"\
                                    --image_dir="../imgs/img13.jpg"\
                                    --e2e_model_dir="../e2e_server_pgnetA_infer"\
                                    --e2e_pgnet_valid_set="totaltext" --use_gpu=False
# Out:
# [2023/02/02 09:29:18] ppocr INFO: Predict time of ../imgs/img13.jpg: 1.3914122581481934
# [2023/02/02 09:29:18] ppocr INFO: The visualized image saved in ./inference_results/e2e_res_img13.jpg

# %%
# !python3 tools/infer/predict_e2e.py --e2e_algorithm="PGNet"\
                                    --image_dir="../imgs/obj2.jpg"\
                                    --e2e_model_dir="../e2e_server_pgnetA_infer"\
                                    --e2e_pgnet_valid_set="totaltext" --use_gpu=False
# Out:
# [2023/02/02 09:29:22] ppocr INFO: Predict time of ../imgs/obj2.jpg: 2.429216146469116
# [2023/02/02 09:29:23] ppocr INFO: The visualized image saved in ./inference_results/e2e_res_obj2.jpg

# %%
# !python3 tools/infer/predict_e2e.py --e2e_algorithm="PGNet"\
                                    --image_dir="../imgs/obj1.jpg"\
                                    --e2e_model_dir="../e2e_server_pgnetA_infer"\
                                    --e2e_pgnet_valid_set="totaltext" --use_gpu=False
# Out:
# [2023/02/02 09:29:27] ppocr INFO: Predict time of ../imgs/obj1.jpg: 2.430233955383301
# [2023/02/02 09:29:27] ppocr INFO: The visualized image saved in ./inference_results/e2e_res_obj1.jpg

# %% [markdown]
# PGNet architecture
#
# ![img](snippets/diagram/pgnet3.png)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import tools.infer.utility as utility
from openvino.runtime import Core
from ppocr.data import create_operators,transform
from ppocr.postprocess import build_post_process

# %%
# 指定 PGNet 模型路径
pgnet_path = "../e2e_server_pgnetA_infer/inference.pdmodel"
# 创建 Core 对象
core = Core()
# 载入并编译 PGNet 模型
pgnet = core.compile_model(model=pgnet_path, device_name="CPU")
# 输出 PGNet 模型输入&输出信息
print(pgnet.input)
# Out:
# <bound method PyCapsule.input of <CompiledModel:
# inputs[
# <ConstOutput: names[x] shape[?,3,?,?] type: f32>
# ]
# outputs[
# <ConstOutput: names[save_infer_model/scale_0.tmp_1] shape[?,4,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_1.tmp_1] shape[?,37,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_2.tmp_1] shape[?,2,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_3.tmp_1] shape[?,1,1..,1..] type: f32>
# ]>>

# %%
def img_dst(img):
    plt.figure(figsize=(10,10))
    plt.imshow(img)
    plt.show()

# %%
def clip_det_res(points,img_height,img_width):
    for i in range(points.shape[0]):
        points[i,0] = int(min(max(points[i,0],0),img_width-1))
        points[i,1] = int(min(max(points[i,1],0),img_height-1))
    return points

# %%
def filter_tag_det_res_only_clip(dt_boxes,image_shape):
    img_height,img_width = image_shape[0:2]
    dt_boxes_new = []
    for box in dt_boxes:
        box = clip_det_res(box,img_height,img_width)
        dt_boxes_new.append(box)
        dt_boxes = np.array(dt_boxes_new)
    return dt_boxes

# %%
# 创建 preprocess_op
pre_process_list = [{'E2EResizeForTest':{'max_side_len':768,'valid_set':'totaltext'}},
                    {'NormalizeImage': {'std': [0.229, 0.224, 0.225],
                                        'mean': [0.485, 0.456, 0.406],
                                        'scale': '1./255.',
                                        'order': 'hwc'}},
                    {'ToCHWImage': None},
                    {'KeepKeys':{'keep_keys': ['image', 'shape']}}]

# %%
preprocess_op = create_operators(pre_process_list)
print(preprocess_op)
# Out:
# [<ppocr.data.imaug.operators.E2EResizeForTest object at 0x7fada03a5cd0>, <ppocr.data.imaug.operators.NormalizeImage object at 0x7fada03a59d0>, <ppocr.data.imaug.operators.ToCHWImage object at 0x7fada03a5ee0>, <ppocr.data.imaug.operators.KeepKeys object at 0x7fada03a5d60>]

# %%
postprocess_params= {}
postprocess_params['name']='PGPostProcess'
postprocess_params['score_thresh']=0.5
postprocess_params['character_dict_path']='../models/ic15_dict.txt'
postprocess_params['valid_set']='totaltext'
postprocess_params['mode']='fast'
postprocess_op = build_post_process(postprocess_params)
print(postprocess_op)
# Out:
# <ppocr.postprocess.pg_postprocess.PGPostProcess object at 0x7fad2b1cddc0>

# %%
img_path = '../imgs/crop2.jpg'
image = cv2.imread(img_path)

# %%
data = {'image':image}
data = transform(data,preprocess_op)
print(len(data))
print(data[0].shape)
print(data[1])
# Out:
# 2
# (3, 128, 512)
# [ 72.         315.           1.77777778   1.62539683]

# %%
img,shape_list = data
img = np.expand_dims(img,axis=0)
shape_list = np.expand_dims(shape_list,axis=0)
print('img',image.shape)
print('shape_list',shape_list.shape)
# Out:
# img (72, 315, 3)
# shape_list (1, 4)

# %%
# starttime = time.time()
# Do the inference by OpenVino
outputs = pgnet([img])
print(outputs)
# Out:
# {<ConstOutput: names[save_infer_model/scale_0.tmp_1] shape[?,4,1..,1..] type: f32>: array([[[[-1.63604033e+00, -2.04761839e+00, -1.46980846e+00, ...,
#           -1.55908644e+00, -2.04956055e+00, -1.61238658e+00],
#          [-2.83975673e+00, -3.65946984e+00, -2.68952155e+00, ...,
#           -3.03299952e+00, -3.54845595e+00, -2.69127321e+00],
#          [-2.89541721e+00, -4.05216932e+00, -3.70363021e+00, ...,
#           -4.32524633e+00, -4.63637924e+00, -3.37714505e+00],
#          ...,
#          [-5.10870028e+00, -7.62979507e+00, -7.53607941e+00, ...,
#           -2.95448613e+00, -3.35723948e+00, -2.52964592e+00],
#          [-5.40921354e+00, -8.06824684e+00, -7.88770628e+00, ...,
#           -3.77525592e+00, -4.12092543e+00, -2.99679661e+00],
#          [-5.29787302e+00, -8.16746902e+00, -8.19659233e+00, ...,
#           -4.49502802e+00, -4.65557241e+00, -3.20787311e+00]],
#
#         [[ 8.90147779e-03, -1.56413484e-02, -7.99002592e-03, ...,
#           -4.62030798e-01, -3.56718928e-01, -2.92274922e-01],
#          [-5.53158252e-03, -1.86685342e-02, -4.57074232e-02, ...,
#           -7.38555312e-01, -5.40247142e-01, -4.19351697e-01],
#          [ 7.31288493e-02,  4.84015085e-02,  3.78009006e-02, ...,
#           -1.17329264e+00, -7.74374187e-01, -6.02539003e-01],
#          ...,
#          [ 1.05832100e+00,  1.16028464e+00,  9.23298895e-01, ...,
#           -7.34832436e-02, -2.21850380e-01, -2.24389270e-01],
#          [ 1.17901695e+00,  1.40561020e+00,  1.07116389e+00, ...,
#           -6.51208013e-02, -2.01314956e-01, -2.00683668e-01],
#          [ 9.02647495e-01,  1.26320684e+00,  1.03969526e+00, ...,
#            5.12106530e-02, -8.81515369e-02, -5.02055362e-02]],
#
#         [[ 2.74082732e+00,  3.55160475e+00,  2.68487573e+00, ...,
#            2.87544632e+00,  3.85120058e+00,  3.09446645e+00],
#          [ 3.45322633e+00,  4.38461542e+00,  3.10510707e+00, ...,
#            3.62428212e+00,  4.52601957e+00,  3.55608940e+00],
#          [ 4.30219984e+00,  5.73077011e+00,  4.73059654e+00, ...,
#            2.3800414 ,  1.5385982 ],
#          [ 1.9466556 ,  2.5686426 ,  2.4928637 , ...,  3.6126904 ,
#            3.211934  ,  2.1167302 ],
#          [ 1.896577  ,  2.7259886 ,  2.7727852 , ...,  4.1843514 ,
#            3.4244285 ,  2.1913733 ],
#          ...,
#          [ 3.7892437 ,  5.5253367 ,  5.833554  , ...,  3.384161  ,
#            3.2117465 ,  2.3244023 ],
#          [ 3.5238128 ,  5.3306975 ,  5.814339  , ...,  3.407269  ,
#            3.318902  ,  2.3697565 ],
#          [ 2.5870442 ,  3.780893  ,  4.054658  , ...,  2.4063852 ,
#            2.5001488 ,  1.6716821 ]],
#
#         [[ 0.06074806,  0.05160965, -0.024158  , ..., -0.02563205,
#            0.05365957, -0.0680108 ],
#          [ 0.2932697 ,  0.4148682 ,  0.09938128, ..., -0.3907069 ,
#           -0.35416642, -0.22953545],
#          [ 0.6596221 ,  0.82030404,  0.4829074 , ..., -1.0716511 ,
#           -0.7997673 , -0.46293613],
#          ...,
#          [ 1.5504955 ,  2.0387096 ,  1.845653  , ..., -1.3217639 ,
#           -1.4660019 , -1.155751  ],
#          [ 1.0376346 ,  1.6967105 ,  1.6492932 , ..., -1.241194  ,
#           -1.2575188 , -0.8269928 ],
#          [ 0.6027842 ,  1.2355291 ,  1.1576129 , ..., -0.96345484,
#           -0.9808914 , -0.48875886]]]], dtype=float32), <ConstOutput: names[save_infer_model/scale_3.tmp_1] shape[?,1,1..,1..] type: f32>: array([[[[5.8902133e-05, 2.9215687e-07, 1.1725231e-07, ...,
#           1.5732121e-06, 5.5295686e-06, 5.4962368e-04],
#          [2.4810714e-07, 1.3350690e-10, 3.6851456e-11, ...,
#           7.7445304e-09, 1.3549494e-08, 1.1088620e-05],
#          [7.7347448e-07, 2.2559672e-09, 9.5674695e-09, ...,
#           1.2847225e-07, 6.3165892e-08, 1.6599703e-05],
#          ...,
#          [4.4540620e-06, 1.3586216e-08, 1.0922247e-08, ...,
#           1.3916704e-09, 2.1731901e-10, 3.0694520e-07],
#          [1.7130245e-06, 4.0350270e-09, 3.3576968e-09, ...,
#           2.6029099e-09, 3.9325876e-10, 1.8511317e-07],
#          [1.2399460e-04, 2.3104005e-06, 1.9954794e-06, ...,
#           6.7545272e-07, 1.9105995e-07, 2.0218253e-05]]]], dtype=float32)}

# %%
out_layers = pgnet.output
out_layers
# Out:
# <bound method PyCapsule.output of <CompiledModel:
# inputs[
# <ConstOutput: names[x] shape[?,3,?,?] type: f32>
# ]
# outputs[
# <ConstOutput: names[save_infer_model/scale_0.tmp_1] shape[?,4,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_1.tmp_1] shape[?,37,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_2.tmp_1] shape[?,2,1..,1..] type: f32>,
# <ConstOutput: names[save_infer_model/scale_3.tmp_1] shape[?,1,1..,1..] type: f32>
# ]>>

# %%
preds={}
#           [ 0.2932697 ,  0.4148682 ,  0.09938128, ..., -0.3907069 ,
#            -0.35416642, -0.22953545],
#           [ 0.6596221 ,  0.82030404,  0.4829074 , ..., -1.0716511 ,
#            -0.7997673 , -0.46293613],
#           ...,
#           [ 1.5504955 ,  2.0387096 ,  1.845653  , ..., -1.3217639 ,
#            -1.4660019 , -1.155751  ],
#           [ 1.0376346 ,  1.6967105 ,  1.6492932 , ..., -1.241194  ,
#            -1.2575188 , -0.8269928 ],
#           [ 0.6027842 ,  1.2355291 ,  1.1576129 , ..., -0.96345484,
#            -0.9808914 , -0.48875886]]]], dtype=float32),
#  'f_score': array([[[[5.8902133e-05, 2.9215687e-07, 1.1725231e-07, ...,
#            1.5732121e-06, 5.5295686e-06, 5.4962368e-04],
#           [2.4810714e-07, 1.3350690e-10, 3.6851456e-11, ...,
#            7.7445304e-09, 1.3549494e-08, 1.1088620e-05],
#           [7.7347448e-07, 2.2559672e-09, 9.5674695e-09, ...,
#            1.2847225e-07, 6.3165892e-08, 1.6599703e-05],
#           ...,
#           [4.4540620e-06, 1.3586216e-08, 1.0922247e-08, ...,
#            1.3916704e-09, 2.1731901e-10, 3.0694520e-07],
#           [1.7130245e-06, 4.0350270e-09, 3.3576968e-09, ...,
#            2.6029099e-09, 3.9325876e-10, 1.8511317e-07],
#           [1.2399460e-04, 2.3104005e-06, 1.9954794e-06, ...,
#            6.7545272e-07, 1.9105995e-07, 2.0218253e-05]]]], dtype=float32)}

# %%
print('f_border',preds['f_border'].shape)
print('f_char',preds['f_char'].shape)
print('f_direction',preds['f_direction'].shape)
print('f_score',preds['f_score'].shape)
# Out:
# f_border (1, 4, 32, 128)
# f_char (1, 37, 32, 128)
# f_direction (1, 2, 32, 128)
# f_score (1, 1, 32, 128)

# %%
plt.imshow(preds['f_border'][0][2])
plt.title('f_border')
# Out:
# Text(0.5, 1.0, 'f_border')

# %%
plt.imshow(preds['f_char'][0][36])
plt.title('f_char')
# Out:
# Text(0.5, 1.0, 'f_char')

# %%
plt.imshow(preds['f_direction'][0][0])
plt.title('f_direction')
# Out:
# Text(0.5, 1.0, 'f_direction')

# %%
plt.imshow(preds['f_direction'][0][1])
plt.title('f_direction')
# Out:
# Text(0.5, 1.0, 'f_direction')

# %%
plt.imshow(preds['f_score'][0][0])
plt.title('f_score')
# Out:
# Text(0.5, 1.0, 'f_score')

# %%
post_result = postprocess_op(preds,shape_list)
post_result
# Out:
# {'points': [array([[ 24.40340424,   0.        ],
#          [ 48.53636049,   7.57629204],
#          [ 67.62601689,  13.05168915],
#          [ 85.11985749,  18.28696203],
#          [100.66518992,  22.45711255],
#          [118.04502106,  27.17562294],
#          [114.44779968,  69.91519928],
#          [ 95.9450385 ,  64.89624453],
#          [ 77.43222065,  61.20157242],
#          [ 60.61544202,  56.00849819],
#          [ 44.99653794,  50.55586338],
#          [ 23.16902542,  44.78827286]]),
#   array([[237.87841797,  18.06485939],
#          [251.3888061 ,  13.65636849],
#          [257.74752975,  10.33641815],
#          [264.26299095,   8.17865396],
#          [272.09275335,   5.25643229],
#          [293.07952881,   0.        ],
#          [307.17605591,  38.50549316],
#          [289.42900211,  45.87711239],
#          [282.99461335,  48.21603727],
#          [275.16543299,  51.76454401],
#          [265.72178811,  54.82927895],
#          [247.03811646,  60.28972244]]),
#   array([[116.46641541,  22.77176094],
#          [147.97206268,  26.8829205 ],
#          [169.19388413,  28.5311358 ],
#          [190.32168746,  27.04571772],
#          [211.59746021,  26.15189838],
#          [238.97467041,  20.99534988],
#          [244.54788208,  62.3883934 ],
#          [216.77607089,  65.99042702],
#          [193.71454507,  68.68073845],
#          [170.50719023,  71.42409325],
#          [147.36029238,  71.65825653],
#          [116.35871887,  69.95317841]])],
#  'texts': ['model', 'h2d', 'number']}

# %%
points = post_result['points']
strs = post_result['texts']

# %%
dt_boxes = filter_tag_det_res_only_clip(points,image.shape)
dt_boxes.shape
# Out:
# (3, 12, 2)

# %%
output = utility.draw_e2e_res(dt_boxes, strs,img_path)
plt.imshow(output)

# %% [markdown]
# # SVTR OCR

# %%
import cv2
import os
import numpy as np
import random
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR

# %%
ocr = PaddleOCR(det_model_dir='../models/ch_PP-OCRv3_det_infer',
                rec_model_dir='../models/ch_PP-OCRv3_rec_infer',
                cls_model_dir='../models/ch_ppocr_mobile_v2.0_cls_infer', 
                use_angle_cls=True)
# Out:
# [2023/02/03 13:35:14] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='../models/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_fce_box_type='poly', det_limit_side_len=960, det_limit_type='max', det_model_dir='../models/ch_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_box_type='quad', det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_mem=500, help='==SUPPRESS==', image_dir=None, ir_optim=True, label_list=['0', '180'], lang='ch', layout=True, layout_label_map=None, layout_path_model='lp://PubLayNet/ppyolov2_r50vd_dcn_365e_publaynet/config', max_batch_size=10, max_text_length=25, min_subgraph_size=15, mode='structure', ocr=True, ocr_version='PP-OCRv3', output='./output', precision='fp32', process_id=0, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/greystone/locchuong/ocr-exp/paddle25/ppocr/utils/ppocr_keys_v1.txt', rec_image_shape='3, 48, 320', rec_model_dir='../models/ch_PP-OCRv3_rec_infer', save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], show_log=True, structure_version='PP-STRUCTURE', table=True, table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_onnx=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', vis_seg_map=False, warmup=False)

# %%
img = cv2.imread(img_path)

# %%
plt.imshow(img)

# %%
ocr.ocr(img,det=False,rec=True,cls=True)
# Out:
# [('Model Number:H2D', 0.9033052325248718)]

# %% [markdown]
# # draw polygon mask

# %% [markdown]
# # PGNET class

# %%
# %cd paddle25
# Out:
# /home/greystone/locchuong/ocr-exp/paddle25

# %%
import cv2
import time
import numpy as np
import tools.infer.utility as utility
import matplotlib.pyplot as plt
from openvino.runtime import Core
from ppocr.data import create_operators,transform
from ppocr.postprocess import build_post_process

# %%
class TextE2E(object):
    def __init__(self,pgnet_path):
        '''
        Init E2E model
        Args:
            pgnet_path (string): directory to E2E PGNet pretrained model
                        example: '../e2e_server_pgnetA_infer/inference.pdmodel' 
        '''
        core = Core()
        self.predictor = core.compile_model(model=pgnet_path, device_name="CPU")
        
        self.e2e_algorithm ='PGNet' # only support pgnet
        self.use_onnx = False
        self.use_openvino = True
        
        pre_process_list = [{'E2EResizeForTest':{'max_side_len':768,
                                                 'valid_set':'totaltext'}},
                            {'NormalizeImage': {'std': [0.229, 0.224, 0.225],
                                                'mean': [0.485, 0.456, 0.406],
                                                'scale': '1./255.',
                                                'order': 'hwc'}},
                            {'ToCHWImage': None},
                            {'KeepKeys':{'keep_keys': ['image', 'shape']}}]
        
        postprocess_params = {}
        postprocess_params['name']='PGPostProcess'
        postprocess_params['score_thresh']=0.5
        postprocess_params['character_dict_path']='../models/ic15_dict.txt'
        postprocess_params['valid_set']='totaltext'
        postprocess_params['mode']='fast'
        
        self.preprocess_op = create_operators(pre_process_list)
        self.postprocess_op = build_post_process(postprocess_params)
        
    def clip_det_res(self, points, img_height, img_width):
        for pno in range(points.shape[0]):
            points[pno, 0] = int(min(max(points[pno, 0], 0), img_width - 1))
            points[pno, 1] = int(min(max(points[pno, 1], 0), img_height - 1))
        return points

    def filter_tag_det_res_only_clip(self, dt_boxes, image_shape):
        img_height, img_width = image_shape[0:2]
        dt_boxes_new = []
        for box in dt_boxes:
            box = self.clip_det_res(box, img_height, img_width)
            dt_boxes_new.append(box)
        dt_boxes = np.array(dt_boxes_new)
        return dt_boxes
    
    def __call__(self,img):
        '''
        infer image by PGNET
        Args:
            img (numpy array): input image
        Return:
            dt_boxes: coordniate of text region, None if error happen
            strs: list of ocr string, None if error happen
            elapse: time elapse, None if error happen
        '''
        ori_img = img.copy() # original image
        # format input data
        data = {'image':img}
        data = transform(data,self.preprocess_op)
        img,shape_list = data
        if img is None:
            return None,None,None
        img = np.expand_dims(img,axis=0)
        shape_list = np.expand_dims(shape_list,axis=0)
        img =img.copy()
        starttime = time.time()
       
        # OpenVINO Support here (Only support OpenVINO)
        if self.use_openvino:
            outputs = self.predictor([img])
            out_layers = self.predictor.output
            preds = {}
            preds['f_border'] = outputs[out_layers(0)]
            preds['f_char'] = outputs[out_layers(1)]
            preds['f_direction'] = outputs[out_layers(2)]
            preds['f_score'] = outputs[out_layers(3)]
            # postprocess result
            post_result = self.postprocess_op(preds,shape_list)
            points = post_result['points']
            strs = post_result['texts']
            dt_boxes = self.filter_tag_det_res_only_clip(points,ori_img.shape)
            elapse = time.time() - starttime
            return dt_boxes,strs,elapse
        else:
           return None,None,None

# %%
pgnet_path = "../e2e_server_pgnetA_infer/inference.pdmodel"
img_path = "../imgs/french_0.jpg"
img = cv2.imread(img_path)
text_detector = TextE2E(pgnet_path)
dt_boxes,strs,elapse = text_detector(img)
output = utility.draw_e2e_res(dt_boxes, strs,img_path)
cv2.imwrite('../output.jpg',output)
plt.imshow(output)

# %% [markdown]
# # references
#
# [Scene Text Image Super-Resolution for OCR](https://stackoverflow.com/questions/64808986/scene-text-image-super-resolution-for-ocr)
#
# [OpenCV Morphological Operations](https://pyimagesearch.com/2021/04/28/opencv-morphological-operations/)
#
# [pgnet openvino](https://aistudio.baidu.com/aistudio/projectdetail/5208774?channelType=0&channel=0)
